# %%
import math

math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
x = 1


for i in range(5):

    x = (x + 2/x) / 2

    print(x)
# Out:
# 1.5
# 1.4166666666666665
# 1.4142156862745097
# 1.4142135623746899
# 1.414213562373095

# %%
round(3.1415926535, 2)

round(3.1415926535, 4)
# Out:
# 3.1416

# %% [markdown]
# Pergunta 1
# Esse cálculo pode ser considerado um exemplo de cálculo direto? Justifique com base na definição apresentada em aula.
#
# Justificativa: Um cálculo direto é caracterizado por obter o resultado aplicando imediatamente uma fórmula, função ou operação conhecida, sem a necessidade de passos intermediários complexos ou de construção de algoritmos para chegar à resposta.

# %% [markdown]
# Pergunta 2
#  O valor obtido melhora a cada iteração? Esse processo pode ser classificado como cálculo direto ou iterativo? Explique.
#
#  Justificativa: O valor melhora a cada iteração porque a cada passo x se aproxima mais da raiz de 2 justificação
# O processo é iterativo porque obtém o resultado por repetição de passos e não de forma imediata justificação

# %% [markdown]
# Pergunta 3
# Qual dos valores é “mais correto”? A resposta depende do problema considerado? Justifique.
#
# Justificativa: O valor round(3.1415926535, 4) é mais correto porque mantém mais casas decimais da constante original e, portanto, representa o número com maior precisão
#
# Sim a resposta depende do problema considerado porque em alguns casos apenas duas casas decimais são suficientes e mais práticas enquanto em outros é necessária maior precisão e então usar quatro casas decimais ou mais é importante
